# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

# !unzip '/content/drive/MyDrive/Colab Notebooks/GeneralDS/data/oxfords_flowers.zip'
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/GeneralDS/data/oxfords_flowers.zip
#   inflating: oxfords_flowers_test.bin
#   inflating: oxfords_flowers_train.bin
#   inflating: oxfords_flowers_valid.bin

# %%
import numpy as np
import pandas as pd

# %%
def read_data(file_path):
    with open(file_path, 'rb') as f:

        header = np.fromfile(f, dtype=np.uint32, count=4)
        num_samples, rows, columns, num_channels = header

        X = np.fromfile(f, dtype=np.uint8, count=num_samples * rows * columns * num_channels)
        X = X.reshape(num_samples, rows, columns, num_channels)

        Y = np.fromfile(f, dtype=np.uint8)
        return X, Y

x_train, y_train = read_data('oxfords_flowers_train.bin')
x_valid, y_valid = read_data('oxfords_flowers_valid.bin')
x_test,  y_test  = read_data('oxfords_flowers_test.bin')

# %% [markdown]
# The classes starts from 1 to 102, But the result of the last layer in fully connected neural network starts from 0. So we should decreament from them

# %%
y_train = y_train - 1
y_valid = y_valid - 1
y_test  = y_test  - 1

# %% [markdown]
# First attempt

# %% [markdown]
# ### Dimensional reduction
#
#
#
# PCA just accepts the dimentional lower or equall than 2, So we need convert every 100*100*3 image pixels into a 30000 flatten array

# %%
from sklearn.decomposition import PCA

pca = PCA(0.95)

x_train_f = x_train.reshape(x_train.shape[0], -1)

pca.fit(x_train_f)
# Out:
# PCA(n_components=0.95)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("# of PCs")
plt.ylabel("Explained variance")
# Out:
# Text(0, 0.5, 'Explained variance')

# %%
x_train_pca = pca.transform(x_train.reshape(x_train.shape[0], -1))
x_valid_pca = pca.transform(x_valid.reshape(x_valid.shape[0], -1))
x_test_pca = pca.transform(x_test.reshape(x_test.shape[0], -1))

print(x_train_pca.shape)
# Out:
# (6149, 1529)

# %%
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Softmax, Dropout, Flatten
from tensorflow.keras.activations import relu, sigmoid, tanh
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.regularizers import l2

model = Sequential()

model.add(Dense(x_train_pca.shape[1], activation=relu, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1), input_shape=(x_train_pca.shape[1],)))
# model.add(Flatten(input_shape=(x_train_pca.shape[1],)))

model.add(Dense(500, activation=relu, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1)))
model.add(Dropout(0.2))
model.add(Dense(500, activation=relu, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1)))
model.add(Dropout(0.2))
model.add(Dense(500, activation=relu, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1)))
model.add(Dropout(0.2))
model.add(Dense(500, activation=relu, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1)))
model.add(Dropout(0.2))
model.add(Dense(500, activation=relu, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1)))
model.add(Dropout(0.2))

model.add(Dense(102, activation='sigmoid', kernel_regularizer=l2(1e-4), bias_regularizer=l2(1e-4)))
model.build()
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_43 (Dense)            (None, 1529)              2339370
#
#  dense_44 (Dense)            (None, 500)               765000
#
#  dropout_30 (Dropout)        (None, 500)               0
#
#  dense_45 (Dense)            (None, 500)               250500
#
#  dropout_31 (Dropout)        (None, 500)               0
#
#  dense_46 (Dense)            (None, 500)               250500
#
#  dropout_32 (Dropout)        (None, 500)               0
#
#  dense_47 (Dense)            (None, 500)               250500
#
#  dropout_33 (Dropout)        (None, 500)               0
#
#  dense_48 (Dense)            (None, 500)               250500
#
#  dropout_34 (Dropout)        (None, 500)               0
#
#  dense_49 (Dense)            (None, 102)               51102
#
# =================================================================
# Total params: 4,157,472
# Trainable params: 4,157,472
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate = 0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

early_stop = 32
earlyStop = EarlyStopping(monitor='val_loss', patience=early_stop, verbose=1, mode='auto')

check_point_name = 'best_weight.hdf5'
check_point = ModelCheckpoint(filepath = check_point_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit(x_train_pca, y_train,
                    batch_size=32,
                    epochs=150,
                    verbose=1,
                    validation_data=(x_valid_pca, y_valid),
                    callbacks=[earlyStop, check_point],
                    shuffle=True)
# Out:
# Epoch 1/150
# 185/193 [===========================>..] - ETA: 0s - loss: 469.9613 - accuracy: 0.0169
# Epoch 1: val_loss improved from inf to 420.04202, saving model to best_weight.hdf5
# 193/193 [==============================] - 4s 9ms/step - loss: 468.4533 - accuracy: 0.0169 - val_loss: 420.0420 - val_accuracy: 0.0186
# ...
# Epoch 74/150
# 185/193 [===========================>..] - ETA: 0s - loss: 3.2268 - accuracy: 0.5353
# Epoch 74: val_loss did not improve from 4.31364
# 193/193 [==============================] - 1s 6ms/step - loss: 3.2261 - accuracy: 0.5363 - val_loss: 5.5645 - val_accuracy: 0.1461
# Epoch 75/150
# 186/193 [===========================>..] - ETA: 0s - loss: 3.1467 - accuracy: 0.5565
# Epoch 75: val_loss did not improve from 4.31364
# 193/193 [==============================] - 1s 7ms/step - loss: 3.1502 - accuracy: 0.5554 - val_loss: 5.6822 - val_accuracy: 0.1373
# Epoch 75: early stopping

# %% [markdown]
# As you can see, the first model with PCA of 95% accuracy has 52% accuracy in training data and 12% in validation data `at the same time`
# So the early stoping cuts the training process. next we try `Data Agmentation` like flipping images or shifting into four direction to decrease the rate of Overfit

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)
SKIP = 5
plt.plot(epochs[SKIP:], loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(epochs[SKIP:], loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.ylim(0, 25)
plt.xlim(25, 75)
plt.show()

# %% [markdown]
# Second attempt

# %%
from keras import regularizers
# import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
from keras.regularizers import l2

model = Sequential()

# kernels

model.add(Conv2D(filters=32, kernel_size=3, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1), strides=1, input_shape=(100, 100, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=3, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1), strides=1))
model.add(Activation('relu'))
model.add(Conv2D(filters=64, kernel_size=3, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1), strides=1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=128, kernel_size=3, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1), strides=1))
model.add(Activation('relu'))
model.add(Conv2D(filters=128, kernel_size=3, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1), strides=1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.01))

# fully connected

model.add(Flatten())

from tensorflow.keras.activations import relu, softmax

model.add(Dense(500, activation=relu, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1)))
model.add(Dropout(0.01))
model.add(Dense(500, activation=relu, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1)))
model.add(Dropout(0.01))
model.add(Dense(500, activation=relu, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1)))
model.add(Dropout(0.5))

model.add(Dense(102, activation=softmax, kernel_regularizer=l2(1e-1), bias_regularizer=l2(1e-1)))
model.build()
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 98, 98, 32)        896
#
#  activation_15 (Activation)  (None, 98, 98, 32)        0
#
#  max_pooling2d_9 (MaxPooling  (None, 49, 49, 32)       0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 47, 47, 64)        18496
#
#  activation_16 (Activation)  (None, 47, 47, 64)        0
#
#  conv2d_17 (Conv2D)          (None, 45, 45, 64)        36928
#
#  activation_17 (Activation)  (None, 45, 45, 64)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 20, 20, 128)       73856
#
#  activation_18 (Activation)  (None, 20, 20, 128)       0
#
#  conv2d_19 (Conv2D)          (None, 18, 18, 128)       147584
#
#  activation_19 (Activation)  (None, 18, 18, 128)       0
#
#  max_pooling2d_11 (MaxPoolin  (None, 9, 9, 128)        0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 9, 9, 128)         0
#
#  flatten_3 (Flatten)         (None, 10368)             0
#
#  dense_4 (Dense)             (None, 500)               5184500
#
#  dropout_7 (Dropout)         (None, 500)               0
#
#  dense_5 (Dense)             (None, 500)               250500
#
#  dropout_8 (Dropout)         (None, 500)               0
#
#  dense_6 (Dense)             (None, 500)               250500
#
#  dropout_9 (Dropout)         (None, 500)               0
#
#  dense_7 (Dense)             (None, 102)               51102
#
# =================================================================
# Total params: 6,014,362
# Trainable params: 6,014,362
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam, RMSprop

model.compile(optimizer=Adam(learning_rate = 0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

early_stop = 32
earlyStop = EarlyStopping(monitor='val_loss', patience=early_stop, verbose=1, mode='auto')

check_point_name = 'best_weight.hdf5'
check_point = ModelCheckpoint(filepath = check_point_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit(x_train, y_train,
                    batch_size=32,
                    epochs=400,
                    verbose=1,
                    validation_data=(x_valid, y_valid),
                    callbacks=[earlyStop, check_point],
                    shuffle=True)
# Out:
# Epoch 1/400
# 193/193 [==============================] - ETA: 0s - loss: 184.4217 - accuracy: 0.0519
# Epoch 1: val_loss improved from inf to 132.88156, saving model to best_weight.hdf5
# 193/193 [==============================] - 10s 26ms/step - loss: 184.4217 - accuracy: 0.0519 - val_loss: 132.8816 - val_accuracy: 0.0353
# ...
# Epoch 188/400
# 192/193 [============================>.] - ETA: 0s - loss: 3.4224 - accuracy: 0.4323
# Epoch 188: val_loss did not improve from 3.75144
# 193/193 [==============================] - 5s 24ms/step - loss: 3.4220 - accuracy: 0.4323 - val_loss: 3.7705 - val_accuracy: 0.3422
# Epoch 189/400
# 191/193 [============================>.] - ETA: 0s - loss: 3.4378 - accuracy: 0.4331
# Epoch 189: val_loss did not improve from 3.75144
# 193/193 [==============================] - 5s 24ms/step - loss: 3.4363 - accuracy: 0.4336 - val_loss: 3.8022 - val_accuracy: 0.3314
# Epoch 189: early stopping

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
SKIP = 10
plt.plot(epochs[SKIP:], loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Third attempt

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

data_generator = ImageDataGenerator(rotation_range=90,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2,
                                    shear_range=0.2,
                                    zoom_range=0.2,
                                    horizontal_flip=True,
                                    vertical_flip=True,
                                    fill_mode='constant')

train_generator = data_generator.flow(x_train, y_train, batch_size=4)
valid_generator = data_generator.flow(x_valid, y_valid, batch_size=4)

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=3, kernel_regularizer=l2(1e-2), bias_regularizer=l2(1e-2), strides=1, input_shape=(100, 100, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=3, kernel_regularizer=l2(1e-2), bias_regularizer=l2(1e-2), strides=1))
model.add(Activation('relu'))
model.add(Conv2D(filters=64, kernel_size=3, kernel_regularizer=l2(1e-2), bias_regularizer=l2(1e-2), strides=1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=128, kernel_size=3, kernel_regularizer=l2(1e-2), bias_regularizer=l2(1e-2), strides=1))
model.add(Activation('relu'))
model.add(Conv2D(filters=128, kernel_size=3, kernel_regularizer=l2(1e-2), bias_regularizer=l2(1e-2), strides=1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.01))

# fully connected

model.add(Flatten())

model.add(Dense(1500, activation=relu, kernel_regularizer=l2(1e-2), bias_regularizer=l2(1e-2)))
model.add(Dropout(0.01))

model.add(Dense(102, activation='softmax', kernel_regularizer=l2(1e-4), bias_regularizer=l2(1e-4)))
model.build()
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 98, 98, 32)        896
#
#  activation_30 (Activation)  (None, 98, 98, 32)        0
#
#  max_pooling2d_18 (MaxPoolin  (None, 49, 49, 32)       0
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 47, 47, 64)        18496
#
#  activation_31 (Activation)  (None, 47, 47, 64)        0
#
#  conv2d_32 (Conv2D)          (None, 45, 45, 64)        36928
#
#  activation_32 (Activation)  (None, 45, 45, 64)        0
#
#  max_pooling2d_19 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 20, 20, 128)       73856
#
#  activation_33 (Activation)  (None, 20, 20, 128)       0
#
#  conv2d_34 (Conv2D)          (None, 18, 18, 128)       147584
#
#  activation_34 (Activation)  (None, 18, 18, 128)       0
#
#  max_pooling2d_20 (MaxPoolin  (None, 9, 9, 128)        0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 9, 9, 128)         0
#
#  flatten_6 (Flatten)         (None, 10368)             0
#
#  dense_12 (Dense)            (None, 1500)              15553500
#
#  dropout_15 (Dropout)        (None, 1500)              0
#
#  dense_13 (Dense)            (None, 102)               153102
#
# =================================================================
# Total params: 15,984,362
# Trainable params: 15,984,362
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate = 0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

early_stop = 32
earlyStop = EarlyStopping(monitor='val_loss', patience=early_stop, verbose=1, mode='auto')

check_point_name = 'best_weight.hdf5'
check_point = ModelCheckpoint(filepath = check_point_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit_generator(train_generator,
                              epochs=50,
                              verbose=1,
                              validation_data=valid_generator,
                              callbacks=[earlyStop, check_point],
                              shuffle=True)
# Out:
# Epoch 1/50
# <ipython-input-22-41499aa4e83a>:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator,
# 1537/1538 [============================>.] - ETA: 0s - loss: 20.8617 - accuracy: 0.1007
# Epoch 1: val_loss improved from inf to 14.63709, saving model to best_weight.hdf5
# 1538/1538 [==============================] - 33s 19ms/step - loss: 20.8585 - accuracy: 0.1007 - val_loss: 14.6371 - val_accuracy: 0.0892
# Epoch 2/50
# 1536/1538 [============================>.] - ETA: 0s - loss: 10.8051 - accuracy: 0.1863
# Epoch 2: val_loss improved from 14.63709 to 8.57094, saving model to best_weight.hdf5
# 1538/1538 [==============================] - 28s 18ms/step - loss: 10.8019 - accuracy: 0.1862 - val_loss: 8.5709 - val_accuracy: 0.1186
# ...
# Epoch 50/50
# 1537/1538 [============================>.] - ETA: 0s - loss: 2.1670 - accuracy: 0.6487
# Epoch 50: val_loss improved from 2.76955 to 2.74412, saving model to best_weight.hdf5
# 1538/1538 [==============================] - 29s 19ms/step - loss: 2.1670 - accuracy: 0.6486 - val_loss: 2.7441 - val_accuracy: 0.5343

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)
SKIP = 5
plt.plot(epochs[SKIP:], loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

def show_confusion_matrix(y_true, y_pred):
    classes = unique_labels(y_true, y_pred)

    # Create the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Plot the confusion matrix
    plt.figure(figsize=(12, 10))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    # plt.xticks(tick_marks, classes, rotation=90)
    # plt.yticks(tick_marks, classes)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')

    # Add the count values in each cell
    # for i in range(len(classes)):
    #     for j in range(len(classes)):
    #         plt.text(j, i, str(cm[i, j]), ha='center', va='center')

    plt.tight_layout()
    plt.show()

# %%
# Create the y_pred of x_test datas

def predict(x):
  y_pred_1 = model.predict(x)
  y_pred = []
  for record in range(len(x)):
    y_pred.append(y_pred_1[record].argmax()+1)

  y_pred = np.array(y_pred)
  y_pred = y_pred - 1

  return y_pred


from sklearn.metrics import accuracy_score

print(accuracy_score(predict(x_test), y_test))
show_confusion_matrix(y_test, predict(x_test))
# Out:
# 32/32 [==============================] - 0s 6ms/step
# 0.4372549019607843
# 32/32 [==============================] - 0s 5ms/step

# %%
def predict(number):
  tst = np.ndarray((1, 100, 100, 3))
  tst[0] = x_test[number]
  predict_value = np.argmax(model.predict(tst))
  print('It belongs to class ', predict_value+1, 'th')
  i = 1
  plt.figure().set_figwidth(30)
  plt.figure().set_figheight(5)

  plt.subplot(2,3,i)
  plt.imshow(x_test[number])
  for count in range(x_train.shape[0]):
    if(y_train[count] == predict_value):
      i = i + 1
      if(i>6):
        break
      plt.subplot(2,3,i)
      plt.imshow(x_train[count])

  plt.show()

# %%
predict(170)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# It belongs to class  17 th
